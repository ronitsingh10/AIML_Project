# %%
import glob
import os
import librosa
import numpy as np
import pretty_midi

# %%
# Constants

MIDInotes_Range = [librosa.note_to_midi('A0'), librosa.note_to_midi('C8')]
Sample_Rate = 16000
Bins_per_octave = 36
n_octaves = 7
Hop_length = 512
spec_fmin = librosa.note_to_hz('A0')
val_rate = 1 / 7
n_Bins = n_octaves * Bins_per_octave
win_width = 32
kernel_size = 7
overlap = True

'''''''''
Allow pretty_midi to read MIDI files with absurdly high tick rates.
Useful for reading the MAPS dataset.
https://github.com/craffel/pretty-midi/issues/112
'''''''''

pretty_midi.pretty_midi.MAX_TICK = 1e10

# %%
def MIDI_to_mat(MIDI_path_train, length, len_of_CQT, Range_MIDI=MIDInotes_Range):
    MIDI_data = pretty_midi.PrettyMIDI(MIDI_path_train)
    pianoRoll = MIDI_data.instruments[0].get_piano_roll(fs=len_of_CQT * Sample_Rate / length)
    Ground_truth_Mat = (pianoRoll[Range_MIDI[0]:Range_MIDI[1] + 1, :len_of_CQT] > 0)
    return Ground_truth_Mat

# %%
dataset = ['Valid', 'Test', 'Train']

for data in dataset:

    S_Path = os.path.join('/Users/ronit/Documents/AIML_Project/DataSet', data)
    D_path = os.path.join('/Users/ronit/Documents/AIML_Project/DataSet_P', data)

    if not os.path.exists(D_path):
        os.makedirs(D_path)

    print(S_Path)

    WAVS = [file[:-4] for file in os.listdir(S_Path) if file.endswith('.wav')]
    MIDI = [file[:-4] for file in os.listdir(S_Path) if file.endswith('.mid')]

    pairs = []
    for file in WAVS:
        assert file in MIDI, 'Both the MIDI and WAV files not found'
        pairs.append((file + '.wav', file + '.mid'))
    
    cnt = 0
    for wav, midi in pairs:
        wav_path = os.path.join(S_Path, wav)
        x, sr = librosa.load(wav_path, sr=Sample_Rate)

        # Load the audio from specific path and compute Constant-Q Transform.
        CQT_file = librosa.cqt(x,
                               sr=Sample_Rate,
                               fmin=spec_fmin,
                               hop_length=Hop_length,
                               n_bins=n_Bins,
                               bins_per_octave=Bins_per_octave,
                               scale=False
                               )
        # Taking abs of Constant-Q Transform of given audio as 2D NumPy array
        CQT_abs = np.abs(CQT_file)
        # Converting the frequency data on a logarthmic scale for better visualization
        CQT = np.transpose(librosa.amplitude_to_db(CQT_abs))

        midi_path = os.path.join(S_Path, midi)
        Ground_Truth_mat = MIDI_to_mat(midi_path, len(x), CQT.shape[0])
        MIDI_Train = np.transpose(Ground_Truth_mat)

        # Length of MIDI < length of CQT, then cut CQT
        if MIDI_Train.shape[0] < CQT.shape[0]:
            CQT = CQT[:MIDI_Train.shape[0],:]
        # --> TODO : ADD one more condition


        # --> Processing WAV files
        W_temp_path = os.path.join(D_path, wav, 'WAV')
        if not os.path.exists(W_temp_path):
            os.makedirs(W_temp_path)
            
        W_path = os.path.join(W_temp_path, wav[:-4]) + '_CQT.npy'
        np.save(W_path, CQT)
        
        CQT_matrix = np.array(np.load(W_path))
        len_CQT = CQT_matrix.shape[0]
        nb_win = int(len_CQT / win_width)
        
        W = CQT_matrix.shape[1]
        # Adding Padding
        Mat = np.concatenate([np.zeros([int(kernel_size / 2), W]), CQT_matrix, np.zeros([int(kernel_size / 2), W])], axis = 0)
        cut_Mat = [Mat[i * win_width:(i + 1) * win_width+kernel_size-1,:] for i in range(nb_win)]
        
        CQT_cut_Mat = np.asarray(cut_Mat)
        os.remove(W_path)
        
        X = CQT_cut_Mat if cnt == 0 else np.concatenate((X, CQT_cut_Mat), axis = 0)
        
        # --> Processing MIDI files   
        M_temp_path = os.path.join(D_path, midi, 'MIDI')
        if not os.path.exists(M_temp_path):
            os.makedirs(M_temp_path)
            
        M_path = os.path.join(M_temp_path, midi[:-4]) + '_LABEL.npy'
        np.save(M_path, MIDI_Train)
        
        MIDI_matrix = np.array(np.load(M_path))
        len_MIDI = MIDI_matrix.shape[0]
        nb_win_ = int(len_MIDI / win_width)
        
        M = MIDI_matrix.shape[1]
        # Adding Padding
        Mat_ = np.concatenate([np.zeros([int(kernel_size / 2), M]), MIDI_matrix, np.zeros([int(kernel_size / 2), M])], axis = 0)
        cut_Mat_ = [Mat_[i * win_width:(i + 1) * win_width+kernel_size-1,:] for i in range(nb_win_)]
        
        MIDI_cut_Mat = np.asarray(cut_Mat_)
        os.remove(M_path)

        Y = MIDI_cut_Mat if cnt == 0 else np.concatenate((Y, MIDI_cut_Mat), axis = 0)
        
        print('Processed', wav[:-4], "File No:", cnt)
        cnt += 1
        
        os.rmdir(W_temp_path)
        os.rmdir(M_temp_path)
        os.rmdir(os.path.join(D_path, wav))
        os.rmdir(os.path.join(D_path, midi))
    
    X_ = np.expand_dims(X, axis = -2)
    Y_ = np.expand_dims(Y, axis = -2)
    
    CQT_final_Path = os.path.join(D_path, 'X_final_') + 'CQT_.npy'
    MIDI_final_Path = os.path.join(D_path, 'Y_final_') + 'Label_.npy'
    np.save(CQT_final_Path, X_)
    np.save(MIDI_final_Path, Y_)
# Out:
# /Users/ronit/Documents/AIML_Project/DataSet/Valid
# Processed MAPS_MUS-mond_2_SptkBGCl File No: 0
# Processed MAPS_MUS-mond_1_SptkBGAm File No: 1
# Processed MAPS_MUS-chpn_op10_e05_SptkBGAm File No: 2
# Processed MAPS_MUS-liz_et3_AkPnStgb File No: 3
# Processed MAPS_MUS-mendel_op53_5_AkPnCGdD File No: 4
# Processed MAPS_MUS-scn15_13_AkPnStgb File No: 5
# Processed MAPS_MUS-chp_op18_AkPnCGdD File No: 6
# Processed MAPS_MUS-grieg_walzer_SptkBGCl File No: 7
# Processed MAPS_MUS-waldstein_3_SptkBGCl File No: 8
# /Users/ronit/Documents/AIML_Project/DataSet/Test
# Processed MAPS_MUS-schu_143_1_ENSTDkAm File No: 0
# Processed MAPS_MUS-liz_rhap12_ENSTDkAm File No: 1
# Processed MAPS_MUS-mz_333_3_ENSTDkCl File No: 2
# Processed MAPS_MUS-schub_d760_3_ENSTDkAm File No: 3
# Processed MAPS_MUS-scn15_11_ENSTDkAm File No: 4
# Processed MAPS_MUS-ty_maerz_ENSTDkAm File No: 5
# Processed MAPS_MUS-scn15_12_ENSTDkCl File No: 6
# Processed MAPS_MUS-grieg_butterfly_ENSTDkCl File No: 7
# Processed MAPS_MUS-mz_332_2_ENSTDkCl File No: 8
# Processed MAPS_MUS-chpn-p19_ENSTDkCl File No: 9
# Processed MAPS_MUS-schu_143_3_ENSTDkCl File No: 10
# Processed MAPS_MUS-mz_333_2_ENSTDkCl File No: 11
# Processed MAPS_MUS-ty_mai_ENSTDkAm File No: 12
# Processed MAPS_MUS-liz_et_trans5_ENSTDkCl File No: 13
# Processed MAPS_MUS-deb_clai_ENSTDkCl File No: 14
# Processed MAPS_MUS-deb_menu_ENSTDkCl File No: 15
# Processed MAPS_MUS-liz_et6_ENSTDkCl File No: 16
# Processed MAPS_MUS-bor_ps6_ENSTDkCl File No: 17
# Processed MAPS_MUS-waldstein_1_ENSTDkAm File No: 18
# Processed MAPS_MUS-scn16_4_ENSTDkAm File No: 19
# Processed MAPS_MUS-bk_xmas1_ENSTDkCl File No: 20
# Processed MAPS_MUS-pathetique_3_ENSTDkAm File No: 21
# Processed MAPS_MUS-mz_331_2_ENSTDkCl File No: 22
# Processed MAPS_MUS-chpn_op7_1_ENSTDkAm File No: 23
# Processed MAPS_MUS-mz_311_1_ENSTDkCl File No: 24
# Processed MAPS_MUS-chpn_op35_1_ENSTDkAm File No: 25
# Processed MAPS_MUS-chpn-p4_ENSTDkAm File No: 26
# Processed MAPS_MUS-muss_1_ENSTDkAm File No: 27
# Processed MAPS_MUS-ty_november_ENSTDkAm File No: 28
# Processed MAPS_MUS-pathetique_1_ENSTDkCl File No: 29
# Processed MAPS_MUS-liz_rhap09_ENSTDkCl File No: 30
# Processed MAPS_MUS-mz_331_3_ENSTDkCl File No: 31
# Processed MAPS_MUS-pathetique_2_ENSTDkAm File No: 32
# Processed MAPS_MUS-scn15_9_ENSTDkAm File No: 33
# Processed MAPS_MUS-bk_xmas5_ENSTDkCl File No: 34
# Processed MAPS_MUS-scn16_4_ENSTDkCl File No: 35
# Processed MAPS_MUS-scn16_3_ENSTDkCl File No: 36
# Processed MAPS_MUS-bk_xmas1_ENSTDkAm File No: 37
# Processed MAPS_MUS-alb_se2_ENSTDkCl File No: 38
# Processed MAPS_MUS-mz_570_1_ENSTDkCl File No: 39
# Processed MAPS_MUS-chpn-e01_ENSTDkCl File No: 40
# Processed MAPS_MUS-chpn-p14_ENSTDkAm File No: 41
# Processed MAPS_MUS-bk_xmas4_ENSTDkCl File No: 42
# Processed MAPS_MUS-schuim-1_ENSTDkCl File No: 43
# Processed MAPS_MUS-chpn-p15_ENSTDkAm File No: 44
# Processed MAPS_MUS-chpn_op66_ENSTDkAm File No: 45
# Processed MAPS_MUS-liz_rhap09_ENSTDkAm File No: 46
# Processed MAPS_MUS-chpn_op33_2_ENSTDkAm File No: 47
# Processed MAPS_MUS-mz_545_3_ENSTDkCl File No: 48
# Processed MAPS_MUS-chpn_op25_e4_ENSTDkAm File No: 49
# Processed MAPS_MUS-scn15_11_ENSTDkCl File No: 50
# Processed MAPS_MUS-chpn_op25_e3_ENSTDkAm File No: 51
# Processed MAPS_MUS-ty_maerz_ENSTDkCl File No: 52
# Processed MAPS_MUS-grieg_butterfly_ENSTDkAm File No: 53
# Processed MAPS_MUS-mendel_op62_5_ENSTDkAm File No: 54
# Processed MAPS_MUS-scn15_6_ENSTDkAm File No: 55
# Processed MAPS_MUS-liz_rhap02_ENSTDkAm File No: 56
# Processed MAPS_MUS-ty_mai_ENSTDkCl File No: 57
# Processed MAPS_MUS-grieg_kobold_ENSTDkAm File No: 58
# Processed MAPS_MUS-schumm-1_ENSTDkAm File No: 59
# /Users/ronit/Documents/AIML_Project/DataSet/Train
# Processed MAPS_MUS-mond_2_SptkBGCl File No: 0
# Processed MAPS_MUS-chpn-p10_AkPnStgb File No: 1
# Processed MAPS_MUS-mz_331_1_SptkBGCl File No: 2
# Processed MAPS_MUS-mz_332_1_AkPnBsdf File No: 3
# Processed MAPS_MUS-chpn_op7_2_SptkBGAm File No: 4
# Processed MAPS_MUS-chpn_op33_4_SptkBGAm File No: 5
# Processed MAPS_MUS-chpn-p12_AkPnBcht File No: 6
# Processed MAPS_MUS-chpn-p9_AkPnBsdf File No: 7
# Processed MAPS_MUS-mond_1_SptkBGAm File No: 8
# Processed MAPS_MUS-gra_esp_3_SptkBGCl File No: 9
# Processed MAPS_MUS-chpn-p24_AkPnBcht File No: 10
# Processed MAPS_MUS-appass_3_AkPnStgb File No: 11
# Processed MAPS_MUS-chpn_op10_e12_AkPnCGdD File No: 12
# Processed MAPS_MUS-chpn-p2_SptkBGCl File No: 13
# Processed MAPS_MUS-bk_xmas2_AkPnStgb File No: 14
# Processed MAPS_MUS-hay_40_1_AkPnBcht File No: 15
# Processed MAPS_MUS-muss_5_AkPnBcht File No: 16
# Processed MAPS_MUS-liz_et5_AkPnCGdD File No: 17
# Processed MAPS_MUS-scn16_7_SptkBGAm File No: 18
# Processed MAPS_MUS-chpn-p6_SptkBGAm File No: 19
# Processed MAPS_MUS-bor_ps5_AkPnStgb File No: 20
# Processed MAPS_MUS-br_im2_AkPnCGdD File No: 21
# Processed MAPS_MUS-bk_xmas2_SptkBGCl File No: 22
# Processed MAPS_MUS-br_im5_AkPnCGdD File No: 23
# Processed MAPS_MUS-mond_3_AkPnStgb File No: 24
# Processed MAPS_MUS-chpn-p13_AkPnBcht File No: 25
# Processed MAPS_MUS-schub_d960_3_AkPnStgb File No: 26
# Processed MAPS_MUS-chpn-p16_AkPnStgb File No: 27
# Processed MAPS_MUS-schub_d960_3_SptkBGCl File No: 28
# Processed MAPS_MUS-ty_februar_AkPnCGdD File No: 29
# Processed MAPS_MUS-grieg_halling_AkPnBsdf File No: 30
# Processed MAPS_MUS-br_im5_AkPnBsdf File No: 31
# Processed MAPS_MUS-gra_esp_2_AkPnStgb File No: 32
# Processed MAPS_MUS-alb_esp6_SptkBGCl File No: 33
# Processed MAPS_MUS-ty_september_SptkBGAm File No: 34
# Processed MAPS_MUS-chpn_op10_e01_AkPnCGdD File No: 35
# Processed MAPS_MUS-grieg_walzer_AkPnBcht File No: 36
# Processed MAPS_MUS-mz_330_1_SptkBGCl File No: 37
# Processed MAPS_MUS-grieg_elfentanz_SptkBGAm File No: 38
# Processed MAPS_MUS-scn16_2_SptkBGCl File No: 39
# Processed MAPS_MUS-alb_esp2_SptkBGAm File No: 40
# Processed MAPS_MUS-bk_xmas3_AkPnStgb File No: 41
# Processed MAPS_MUS-chpn-p1_AkPnBcht File No: 42
# Processed MAPS_MUS-chpn-p20_AkPnCGdD File No: 43
# Processed MAPS_MUS-chpn_op10_e05_SptkBGAm File No: 44
# Processed MAPS_MUS-liz_et_trans4_SptkBGAm File No: 45
# Processed MAPS_MUS-liz_et4_SptkBGCl File No: 46
# Processed MAPS_MUS-schumm-6_AkPnBcht File No: 47
# Processed MAPS_MUS-chpn_op25_e2_AkPnBcht File No: 48
# Processed MAPS_MUS-ty_dezember_AkPnBsdf File No: 49
# Processed MAPS_MUS-schub_d760_1_AkPnBcht File No: 50
# Processed MAPS_MUS-schumm-3_AkPnStgb File No: 51
# Processed MAPS_MUS-liz_et3_AkPnStgb File No: 52
# Processed MAPS_MUS-schub_d960_3_AkPnCGdD File No: 53
# Processed MAPS_MUS-ty_februar_SptkBGCl File No: 54
# Processed MAPS_MUS-scn15_7_SptkBGAm File No: 55
# Processed MAPS_MUS-chpn-p11_AkPnCGdD File No: 56
# Processed MAPS_MUS-chpn-p21_AkPnBsdf File No: 57
# Processed MAPS_MUS-chpn-p11-format0_AkPnCGdD File No: 58
# Processed MAPS_MUS-chp_op31_AkPnBcht File No: 59
# Processed MAPS_MUS-liz_et1_SptkBGAm File No: 60
# Processed MAPS_MUS-bach_847_AkPnStgb File No: 61
# Processed MAPS_MUS-br_im5_SptkBGCl File No: 62
# Processed MAPS_MUS-liz_et2_AkPnStgb File No: 63
# Processed MAPS_MUS-bach_847_SptkBGCl File No: 64
# Processed MAPS_MUS-mendel_op53_5_AkPnCGdD File No: 65
# Processed MAPS_MUS-chpn_op27_1_AkPnCGdD File No: 66
# Processed MAPS_MUS-scn15_2_SptkBGCl File No: 67
# Processed MAPS_MUS-ty_juli_AkPnBsdf File No: 68
# Processed MAPS_MUS-grieg_zwerge_AkPnBcht File No: 69
# Processed MAPS_MUS-alb_se4_AkPnBsdf File No: 70
# Processed MAPS_MUS-grieg_wanderer_SptkBGAm File No: 71
# Processed MAPS_MUS-scn15_5_SptkBGCl File No: 72
# Processed MAPS_MUS-scn15_7_AkPnBcht File No: 73
# Processed MAPS_MUS-alb_se3_AkPnBsdf File No: 74
# Processed MAPS_MUS-ty_januar_AkPnStgb File No: 75
# Processed MAPS_MUS-mz_333_1_AkPnStgb File No: 76
# Processed MAPS_MUS-bach_846_SptkBGAm File No: 77
# Processed MAPS_MUS-deb_pass_SptkBGAm File No: 78
# Processed MAPS_MUS-alb_esp2_AkPnCGdD File No: 79
# Processed MAPS_MUS-mond_1_AkPnBsdf File No: 80
# Processed MAPS_MUS-chpn-p8_AkPnBcht File No: 81
# Processed MAPS_MUS-chpn-p7_AkPnCGdD File No: 82
# Processed MAPS_MUS-muss_2_AkPnCGdD File No: 83
# Processed MAPS_MUS-bach_847_AkPnBcht File No: 84
# Processed MAPS_MUS-chpn-p1_AkPnBsdf File No: 85
# Processed MAPS_MUS-muss_4_AkPnBsdf File No: 86
# Processed MAPS_MUS-ty_oktober_SptkBGAm File No: 87
# Processed MAPS_MUS-mos_op36_6_AkPnBsdf File No: 88
# Processed MAPS_MUS-br_im6_AkPnStgb File No: 89
# Processed MAPS_MUS-scn15_13_AkPnStgb File No: 90
# Processed MAPS_MUS-br_im2_SptkBGAm File No: 91
# Processed MAPS_MUS-bor_ps1_AkPnCGdD File No: 92
# Processed MAPS_MUS-bach_846_AkPnBcht File No: 93
# Processed MAPS_MUS-alb_se8_SptkBGAm File No: 94
# Processed MAPS_MUS-chp_op18_AkPnCGdD File No: 95
# Processed MAPS_MUS-liz_et2_SptkBGAm File No: 96
# Processed MAPS_MUS-waldstein_2_AkPnCGdD File No: 97
# Processed MAPS_MUS-schumm-2_SptkBGAm File No: 98
# Processed MAPS_MUS-ty_juni_AkPnBsdf File No: 99
# Processed MAPS_MUS-alb_esp3_AkPnCGdD File No: 100
# Processed MAPS_MUS-chp_op31_AkPnStgb File No: 101
# Processed MAPS_MUS-appass_1_AkPnBsdf File No: 102
# Processed MAPS_MUS-grieg_elfentanz_AkPnBsdf File No: 103
# Processed MAPS_MUS-scn15_3_AkPnBcht File No: 104
# Processed MAPS_MUS-alb_se7_AkPnBsdf File No: 105
# Processed MAPS_MUS-chpn-p13_AkPnCGdD File No: 106
# Processed MAPS_MUS-mond_2_SptkBGAm File No: 107
# Processed MAPS_MUS-bach_850_AkPnBsdf File No: 108
# Processed MAPS_MUS-gra_esp_3_SptkBGAm File No: 109
# Processed MAPS_MUS-grieg_walzer_SptkBGCl File No: 110
# Processed MAPS_MUS-bor_ps2_SptkBGAm File No: 111
# Processed MAPS_MUS-chpn_op27_2_AkPnStgb File No: 112
# Processed MAPS_MUS-alb_se6_AkPnStgb File No: 113
# Processed MAPS_MUS-muss_3_SptkBGCl File No: 114
# Processed MAPS_MUS-chpn_op27_2_SptkBGCl File No: 115
# Processed MAPS_MUS-chpn-p3_AkPnBcht File No: 116
# Processed MAPS_MUS-chpn-p6_SptkBGCl File No: 117
# Processed MAPS_MUS-scn16_2_AkPnBcht File No: 118
# Processed MAPS_MUS-alb_se3_AkPnBcht File No: 119
# Processed MAPS_MUS-schuim-3_AkPnStgb File No: 120
# Processed MAPS_MUS-ty_juli_AkPnBcht File No: 121
# Processed MAPS_MUS-alb_esp4_AkPnStgb File No: 122
# Processed MAPS_MUS-schu_143_2_AkPnCGdD File No: 123
# Processed MAPS_MUS-chpn_op35_3_AkPnStgb File No: 124
# Processed MAPS_MUS-grieg_waechter_AkPnBcht File No: 125
# Processed MAPS_MUS-chpn-p7_SptkBGCl File No: 126
# Processed MAPS_MUS-burg_perlen_SptkBGCl File No: 127
# Processed MAPS_MUS-burg_quelle_SptkBGAm File No: 128
# Processed MAPS_MUS-gra_esp_4_AkPnBcht File No: 129
# Processed MAPS_MUS-alb_esp2_AkPnStgb File No: 130
# Processed MAPS_MUS-grieg_wanderer_AkPnBsdf File No: 131
# Processed MAPS_MUS-ty_september_AkPnStgb File No: 132
# Processed MAPS_MUS-liz_rhap10_AkPnBsdf File No: 133
# Processed MAPS_MUS-alb_esp2_SptkBGCl File No: 134
# Processed MAPS_MUS-appass_1_SptkBGCl File No: 135
# Processed MAPS_MUS-waldstein_3_SptkBGCl File No: 136
# Processed MAPS_MUS-scn16_5_SptkBGAm File No: 137
# Processed MAPS_MUS-alb_esp5_SptkBGCl File No: 138

# %%
X_data_Valid = np.load('DataSet_P/Valid/X_final_CQT_.npy')
X_data_Valid.shape
# Out:
# (1998, 38, 1, 252)

# %%
Y_data_Valid = np.load('DataSet_P/Valid/Y_final_Label_.npy')
Y_data_Valid.shape
# Out:
# (1998, 38, 1, 88)

# %%
X_data_Test = np.load('DataSet_P/Test/X_final_CQT_.npy')
X_data_Test.shape
# Out:
# (15219, 38, 1, 252)

# %%
Y_data_Test = np.load('DataSet_P/Test/Y_final_Label_.npy')
Y_data_Test.shape
# Out:
# (15219, 38, 1, 88)

# %%
X_data_Train = np.load('DataSet_P/Train/X_final_CQT_.npy')
X_data_Train.shape
# Out:
# (28721, 38, 1, 252)

# %%
Y_data_Train = np.load('DataSet_P/Train/Y_final_Label_.npy')
Y_data_Train.shape
# Out:
# (28721, 38, 1, 88)

# %%
a3 = np.load('DataSet_P/Train/X_final_CQT_.npy', mmap_mode='r')
a3
# Out:
# memmap([[[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#             0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#          [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#             0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#          [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#             0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#          ...,
#
#          [[-2.24933319e+01, -2.33259106e+01, -2.11815224e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-2.20094490e+01, -2.35525684e+01, -2.09465504e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-2.15774345e+01, -2.38304596e+01, -2.07589703e+01, ...,
#            -3.22830162e+01, -2.27744694e+01, -2.49282036e+01]]],
#
#
#         [[[-2.39244061e+01, -2.33881092e+01, -2.23313541e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-2.34484310e+01, -2.32849808e+01, -2.19118881e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-2.29290295e+01, -2.32740498e+01, -2.15091782e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          ...,
#
#          [[-1.89509411e+01, -1.58471317e+01, -2.43658791e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-1.81895714e+01, -1.59855766e+01, -2.31421432e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-1.75055618e+01, -1.62477474e+01, -2.17603664e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]]],
#
#
#         [[[-2.16545010e+01, -1.63093452e+01, -2.50278759e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-2.07371407e+01, -1.59897938e+01, -2.54106102e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-1.97900963e+01, -1.58647156e+01, -2.52252350e+01, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          ...,
#
#          [[-1.68764534e+01, -5.49101162e+00, -5.87616968e+00, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-1.43900223e+01, -5.10113621e+00, -5.97931814e+00, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#          [[-1.24690552e+01, -4.76809978e+00, -6.09383965e+00, ...,
#            -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]]],
#
#
#         ...,
#
#
#         [[[-2.00924511e+01, -1.50754299e+01, -2.38418388e+01, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[-2.07532482e+01, -1.49862041e+01, -2.34027748e+01, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[-2.15155258e+01, -1.48856544e+01, -2.28034000e+01, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          ...,
#
#          [[-5.63079882e+00, -1.29933567e+01, -9.58599758e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[-5.16728687e+00, -1.43252859e+01, -9.53407860e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[-4.74256420e+00, -1.60525455e+01, -9.47258854e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]]],
#
#
#         [[[-7.23447275e+00, -1.05957136e+01, -9.67830467e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[-6.66461420e+00, -1.11709356e+01, -9.66408730e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[-6.12237930e+00, -1.19776402e+01, -9.64069366e+00, ...,
#            -2.92824554e+01, -2.99770622e+01, -3.21496086e+01]],
#
#          ...,
#
#          [[ 1.34751725e+00, -4.43560982e+00, -8.85760880e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[ 1.20569003e+00, -4.84101582e+00, -8.48166275e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[ 1.02185094e+00, -5.25925064e+00, -8.12819004e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]]],
#
#
#         [[[ 1.69312942e+00, -3.75605488e+00, -1.04743137e+01, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[ 1.59319520e+00, -3.89611673e+00, -9.85342407e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[ 1.48355556e+00, -4.14082956e+00, -9.32592487e+00, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          ...,
#
#          [[ 1.20066106e-01, -6.96871948e+00, -1.78554821e+01, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[ 1.10186096e-02, -7.04767752e+00, -1.78689384e+01, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#          [[-1.30057976e-01, -7.13471031e+00, -1.80663948e+01, ...,
#            -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]]]])

# %%
X_data_Train
# Out:
# array([[[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         ...,
#
#         [[-2.24933319e+01, -2.33259106e+01, -2.11815224e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-2.20094490e+01, -2.35525684e+01, -2.09465504e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-2.15774345e+01, -2.38304596e+01, -2.07589703e+01, ...,
#           -3.22830162e+01, -2.27744694e+01, -2.49282036e+01]]],
#
#
#        [[[-2.39244061e+01, -2.33881092e+01, -2.23313541e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-2.34484310e+01, -2.32849808e+01, -2.19118881e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-2.29290295e+01, -2.32740498e+01, -2.15091782e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         ...,
#
#         [[-1.89509411e+01, -1.58471317e+01, -2.43658791e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-1.81895714e+01, -1.59855766e+01, -2.31421432e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-1.75055618e+01, -1.62477474e+01, -2.17603664e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]]],
#
#
#        [[[-2.16545010e+01, -1.63093452e+01, -2.50278759e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-2.07371407e+01, -1.59897938e+01, -2.54106102e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-1.97900963e+01, -1.58647156e+01, -2.52252350e+01, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         ...,
#
#         [[-1.68764534e+01, -5.49101162e+00, -5.87616968e+00, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-1.43900223e+01, -5.10113621e+00, -5.97931814e+00, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]],
#
#         [[-1.24690552e+01, -4.76809978e+00, -6.09383965e+00, ...,
#           -3.65054741e+01, -3.65054741e+01, -3.65054741e+01]]],
#
#
#        ...,
#
#
#        [[[-2.00924511e+01, -1.50754299e+01, -2.38418388e+01, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[-2.07532482e+01, -1.49862041e+01, -2.34027748e+01, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[-2.15155258e+01, -1.48856544e+01, -2.28034000e+01, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         ...,
#
#         [[-5.63079882e+00, -1.29933567e+01, -9.58599758e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[-5.16728687e+00, -1.43252859e+01, -9.53407860e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[-4.74256420e+00, -1.60525455e+01, -9.47258854e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]]],
#
#
#        [[[-7.23447275e+00, -1.05957136e+01, -9.67830467e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[-6.66461420e+00, -1.11709356e+01, -9.66408730e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[-6.12237930e+00, -1.19776402e+01, -9.64069366e+00, ...,
#           -2.92824554e+01, -2.99770622e+01, -3.21496086e+01]],
#
#         ...,
#
#         [[ 1.34751725e+00, -4.43560982e+00, -8.85760880e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[ 1.20569003e+00, -4.84101582e+00, -8.48166275e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[ 1.02185094e+00, -5.25925064e+00, -8.12819004e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]]],
#
#
#        [[[ 1.69312942e+00, -3.75605488e+00, -1.04743137e+01, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[ 1.59319520e+00, -3.89611673e+00, -9.85342407e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[ 1.48355556e+00, -4.14082956e+00, -9.32592487e+00, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         ...,
#
#         [[ 1.20066106e-01, -6.96871948e+00, -1.78554821e+01, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[ 1.10186096e-02, -7.04767752e+00, -1.78689384e+01, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]],
#
#         [[-1.30057976e-01, -7.13471031e+00, -1.80663948e+01, ...,
#           -4.31358757e+01, -4.31358757e+01, -4.31358757e+01]]]])
